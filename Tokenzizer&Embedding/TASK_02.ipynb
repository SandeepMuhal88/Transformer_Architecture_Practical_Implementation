# %%
import torch

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Text: "Deep learning is powerful"
Tokens: ["Deep", "learning", "is", "powerful"]

# %%
# "cat" → ["c", "a", "t"]

# %%
text = "Tokenization is essential"

tokens = tokenizer.tokenize(text)
ids = tokenizer.convert_tokens_to_ids(tokens)

print(tokens)
print(ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 text = "Tokenization is essential"
# ----> 3 tokens = tokenizer.tokenize(text)
#       4 ids = tokenizer.convert_tokens_to_ids(tokens)
#       6 print(tokens)
#
# NameError: name 'tokenizer' is not defined
